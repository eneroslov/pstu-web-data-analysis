# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %%
import requests
import json
from typing import Dict, List, Union
import re
import os
from datetime import datetime
import bs4
from hashlib import md5

# %%
def get_wikipedia_data(query: str, lang: str = "ru", related_depth: int = 1) -> Dict[str, Union[str, List[str]]]:
    url = f"https://{lang}.wikipedia.org/w/api.php"
    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'extracts|info|links|images',
        'exintro': True,  # только вводный раздел.
        'explaintext': True,  # вывод текста без HTML-тегов.
        'titles': query,
        'inprop': 'url',
        # 'pllimit': 'max',  # Максимальное количество ссылок.
        'imlimit': 'max'   # Максимальное количество изображений.
    }

    response = requests.get(url, params=params)
    data = response.json()

    page = next(iter(data['query']['pages'].values()))
    result = {
        'title': page.get('title'),
        'extract': page.get('extract'),
        'url': page.get('fullurl'),
        'links': [],
        'images': [],
        'related_articles': []
    }

    if 'links' in page:
        base_url = f"https://{lang}.wikipedia.org/wiki/"
        result['links'] = [base_url + link['title'].replace(' ', '_') for link in page['links']]

    if 'images' in page:
        image_titles = [img['title'] for img in page['images'] if img['title'].lower().endswith(('.jpg', '.jpeg', '.png', '.gif'))]

        for image_title in image_titles:
            image_info_url = f"https://{lang}.wikipedia.org/w/api.php"
            image_info_params = {
                'action': 'query',
                'format': 'json',
                'titles': image_title,
                'prop': 'imageinfo',
                'iiprop': 'url'
            }
            image_response = requests.get(image_info_url, params=image_info_params)
            image_data = image_response.json()
            image_page = next(iter(image_data['query']['pages'].values()))
            if 'imageinfo' in image_page:
                result['images'].append(image_page['imageinfo'][0]['url'])

    if 'links' in page and related_depth > 0:
        related_articles = []
        for link in page['links']:
            related_article = get_wikipedia_data(link['title'], lang=lang, related_depth=0)
            related_articles.append(related_article)
        result['related_articles'] = related_articles

    return result

# %%
def get_wikidata_data(query: str, lang: str = "ru", related_depth: int = 1) -> Dict[str, Union[str, Dict]]:
    url = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'wbsearchentities',
        'search': query,
        'language': lang,
        'format': 'json',
        'limit': 1
    }

    response = requests.get(url, params=params)
    data = response.json()

    entity_id = data['search'][0]['id']
    entity_url = f"https://www.wikidata.org/wiki/Special:EntityData/{entity_id}.json"
    entity_response = requests.get(entity_url)
    entity_data = entity_response.json()

    entity = entity_data['entities'][entity_id]

    result = {
        'title': entity['labels'][lang]['value'] if lang in entity['labels'] else "Название не найдено",
        'description': entity.get('descriptions', {}).get(lang, {}).get('value', "Описание не найдено"),
        'url': f"https://www.wikidata.org/wiki/{entity_id}",
        'images': [],
        'related_entities': []
    }

    if 'claims' in entity and 'P18' in entity['claims']:
        image_titles = [img_claim['mainsnak']['datavalue']['value']
                        for img_claim in entity['claims']['P18']
                        if 'mainsnak' in img_claim and 'datavalue' in img_claim['mainsnak']]

        for image_title in image_titles:
            image_url = f"https://commons.wikimedia.org/wiki/Special:FilePath/{image_title.replace(' ', '_')}"
            result['images'].append(image_url)

    if 'claims' in entity and related_depth > 0:
        related_entities = []
        for prop, claims in entity['claims'].items():
            for claim in claims:
                if 'mainsnak' in claim and 'datavalue' in claim['mainsnak']:
                    if claim['mainsnak']['datavalue']['type'] == 'wikibase-entityid':
                        related_entity_id = claim['mainsnak']['datavalue']['value']['id']
                        related_entity = get_wikidata_data(related_entity_id, lang=lang, related_depth=0)
                        related_entities.append(related_entity)
        result['related_entities'] = related_entities

    return result

# %%
def parse_wikitext(content: str) -> Dict[str, Union[str, List[str]]]:
    result = {
        'значение': [],
        'синонимы': [],
        'антонимы': [],
        'гиперонимы': [],
        'гипонимы': []
    }

    value_pattern = re.compile(r'==== Значение ====\n(.*?)(?=\n====)', re.DOTALL)
    synonym_pattern = re.compile(r'==== Синонимы ====\n(.*?)(?=\n====)', re.DOTALL)
    antonym_pattern = re.compile(r'==== Антонимы ====\n(.*?)(?=\n====)', re.DOTALL)
    hypernym_pattern = re.compile(r'==== Гиперонимы ====\n(.*?)(?=\n====)', re.DOTALL)
    hyponym_pattern = re.compile(r'==== Гипонимы ====\n(.*?)(?=\n====)', re.DOTALL)

    value_match = value_pattern.search(content)
    if value_match:
        result['значение'] = [v.strip() for v in value_match.group(1).split('\n#') if v]
    synonym_match = synonym_pattern.search(content)
    if synonym_match:
        result['синонимы'] = [s.strip() for s in synonym_match.group(1).split('\n#') if s]
    antonym_match = antonym_pattern.search(content)
    if antonym_match:
        result['антонимы'] = [a.strip() for a in antonym_match.group(1).split('\n#') if a]
    hypernym_match = hypernym_pattern.search(content)
    if hypernym_match:
        result['гиперонимы'] = [h.strip() for h in hypernym_match.group(1).split('\n#') if h]
    hyponym_match = hyponym_pattern.search(content)
    if hyponym_match:
        result['гипонимы'] = [h.strip() for h in hyponym_match.group(1).split('\n#') if h]

    return result

def get_wiktionary_data(query: str, lang: str = "ru", related_depth: int = 1) -> Dict[str, Union[str, List[str]]]:
    def check_variants(variants):
        for variant in variants:
            params = {
                'action': 'query',
                'format': 'json',
                'prop': 'revisions|links',
                'rvprop': 'content',
                'rvslots': '*',
                'titles': variant,
            }
            response = requests.get(f"https://{lang}.wiktionary.org/w/api.php", params=params)
            data = response.json()
            page = next(iter(data['query']['pages'].values()))
            if not page.get('missing') and page.get('missing') != '':
                return page
        return None

    variants = [query, query.lower(), query.capitalize(), query.upper()]

    page = check_variants(variants)
    if page is None:
        return {"error": f"Статья '{query}' не найдена в Викисловаре."}

    result = {
        'title': page.get('title'),
        'extract': '',
        'url': f"https://{lang}.wiktionary.org/wiki/{page.get('title').replace(' ', '_')}",
        'links': [],
        'related_articles': []
    }

    if 'revisions' in page:
        revision_content = page['revisions'][0]['slots']['main'].get('*')
        if revision_content:
            result['extract'] = parse_wikitext(revision_content)

    if 'links' in page:
        base_url = f"https://{lang}.wiktionary.org/wiki/"
        result['links'] = [base_url + link['title'].replace(' ', '_') for link in page['links']]

    if 'links' in page and related_depth > 0:
        related_articles = []
        for link in page['links']:
            related_article = get_wiktionary_data(link['title'], lang=lang, related_depth=0)
            related_articles.append(related_article)
        result['related_articles'] = related_articles

    return result

# %%
def get_commons_data(query: str, lang: str = "commons") -> Dict[str, List[Dict[str, str]]]:
    url = f"https://{lang}.wikimedia.org/w/api.php"
    params = {
        'action': 'query',
        'format': 'json',
        'list': 'search',
        'srsearch': query,
        'srnamespace': 6,  # Ограничение на пространство имен.
    }

    response = requests.get(url, params=params)
    data = response.json()

    print(data)

    result = {
        'title': query,
        'images': [],
    }

    if 'query' in data and 'search' in data['query']:
        for item in data['query']['search']:
            image_title = item['title']
            image_url = f"https://commons.wikimedia.org/wiki/{image_title.replace(' ', '_')}"
            image_description = item.get('snippet', '')

            result['images'].append({
                'title': image_title,
                'url': image_url,
                'description': image_description,
            })

    return result

# %%
def get_picture_of_the_day(lang: str = "en"):
    current_date = datetime.today().isoformat()
    year = datetime.today().year
    month = f"{datetime.today().month:02d}"
    day = f"{datetime.today().day:02d}"

    title = f"Template:Potd/{year}-{month}-{day}"

    url = f"https://commons.wikimedia.org/w/api.php"

    parse_query_params = {
        "action": "parse",
        "format": "json",
        "prop": "text",
        "page": f"{title} ({lang})"
    }

    response = requests.get(url, params=parse_query_params)
    data = response.json()

    if 'parse' not in data:
        print(f"Не удалось найти Картинку дня для {current_date}.")
        return

    potd_caption = data['parse']['text'].get('*')

    potd_soup = bs4.BeautifulSoup(potd_caption, 'html.parser')
    description_div = potd_soup.find('div', class_='description')

    if description_div:
        description = description_div.text.strip()
    else:
        description = "Описание не найдено."

    image_query_params = {
        "action": "query",
        "format": "json",
        "prop": "images",
        "titles": title
    }

    image_response = requests.get(url, params=image_query_params)
    image_data = image_response.json()

    if 'query' in image_data and 'pages' in image_data['query']:
        pages = image_data['query']['pages']
        first_page = next(iter(pages.values()))
        if 'images' in first_page:
            filename = first_page['images'][0]['title'].replace(' ', '_')
        else:
            print(f"Изображение не найдено для {current_date}.")
            return
    else:
        print(f"Изображение не найдено для {current_date}.")
        return

    md5_hash = md5(filename[5:].encode('utf-8')).hexdigest()
    image_url = f"https://upload.wikimedia.org/wikipedia/commons/{md5_hash[0]}/{md5_hash[0:2]}/{filename[5:]}"

    image_filename = f"{current_date}_{filename.split(':')[-1]}"
    text_filename = f"{current_date}_{filename.split(':')[-1].split('.')[0]}.txt"

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:89.0) Gecko/20100101 Firefox/89.0',
        'Referer': f'https://commons.wikimedia.org/wiki/{filename}',  # Можно добавить страницу с файлом в Referer
    }

    image_response = requests.get(image_url, headers=headers)
    if image_response.status_code == 200:
        with open(image_filename, 'wb') as img_file:
            img_file.write(image_response.content)
    else:
        print(f"Не удалось скачать изображение: {image_url}")
        return

    with open(text_filename, 'w', encoding='utf-8') as text_file:
        text_file.write(f"Title: {filename}\n")
        text_file.write(f"Description: {description}\n")
        text_file.write(f"Image URL: {image_url}\n")

# %%
def collect_data(query: str) -> Dict[str, Union[str, List]]:
    result = {
        'wikipedia': get_wikipedia_data(query),
        'wikidata': get_wikidata_data(query),
        'wiktionary': get_wiktionary_data(query),
        'commons': get_commons_data(query)
    }

    get_picture_of_the_day()

    return result

# %%
query = "Чёрная металлургия"
data = collect_data(query)

print(json.dumps(data, ensure_ascii=False, indent=4))
# Out:
# {'batchcomplete': '', 'continue': {'sroffset': 10, 'continue': '-||'}, 'query': {'searchinfo': {'totalhits': 57, 'suggestion': 'чёрной металлургии', 'suggestionsnippet': '<em>чёрной металлургии</em>'}, 'search': [{'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (6).png', 'pageid': 149204146, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (6).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:29Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 17.png', 'pageid': 149204144, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 17.png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:29Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (7).png', 'pageid': 149204147, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (7).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:29Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (1).png', 'pageid': 149204139, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (1).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:13Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (5).png', 'pageid': 149204143, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (5).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:28Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (4).png', 'pageid': 149204142, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (4).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:29Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (2).png', 'pageid': 149204140, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (2).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:28Z'}, {'ns': 6, 'title': 'File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (3).png', 'pageid': 149204141, 'size': 2339, 'wordcount': 103, 'snippet': 'DescriptionИзвестия высших учебных заведений. <span class="searchmatch">Черная</span> <span class="searchmatch">металлургия</span>. 1998, выпуск 12 (3).png English: Physical chemistry and theory of metallurgical processes', 'timestamp': '2024-07-01T21:01:29Z'}, {'ns': 6, 'title': 'File:Металлургия Волжской Булгарии 13-14 века.JPG', 'pageid': 45041788, 'size': 1530, 'wordcount': 162, 'snippet': 'Description<span class="searchmatch">Металлургия</span> Волжской Булгарии 13-14 века.JPG Русский: Ведущую отрасль ремесла Волжской Булгарии пред-ставляла собой <span class="searchmatch">черная</s ...
# {
#     "wikipedia": {
#         "title": "Чёрная металлургия",
#         "extract": "Чёрная металлургия — отрасль тяжёлой промышленности, объединяющая технологически и организационно предприятия по добыче и обогащению рудного и нерудного сырья, по производству огнеупоров, продуктов коксохимической промышленности, чугуна, стали, проката, ферросплавов, стальных и чугунных труб, а также изделий дальнейшего передела (рельсовых скреплений, белой жести, оцинкованного железа), металлических порошков чёрных металлов. Основным исходным сырьём для получения чёрных металлов являются железная руда, коксующиеся угли и руды легирующих металлов.",
#         "url": "https://ru.wikipedia.org/wiki/%D0%A7%D1%91%D1%80%D0%BD%D0%B0%D1%8F_%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%8F",
#         "links": [
#             "https://ru.wikipedia.org/wiki/Arcelor_Mittal",
#             "https://ru.wikipedia.org/wiki/Gerdau",
#             "https://ru.wikipedia.org/wiki/POSCO",
#             "https://ru.wikipedia.org/wiki/Tata_Steel",
#             "https://ru.wikipedia.org/wiki/Techint",
#             "https://ru.wikipedia.org/wiki/U.S._Steel",
#             "https://ru.wikipedia.org/wiki/Wayback_Machine",
#             "https://ru.wikipedia.org/wiki/Австралия",
#             "https://ru.wikipedia.org/wiki/Агломерат_(металлургия)",
#             "https://ru.wikipedia.org/wiki/Агломерационная_машина"
#         ],
#         "images": [
#             "https://upload.wikimedia.org/wikipedia/commons/8/80/Algoma_Steel.jpg",
#             "https://upload.wikimedia.org/wikipedia/commons/a/a9/GwangyangIronworks.jpg",
#             "https://upload.wikimedia.org/wikipedia/commons/b/bd/Nizhniy_tagil_ntmk_main_entrance.JPG",
#             "https://upload.wikimedia.org/wikipedia/commons/0/0b/Nizhny_Tagil_metallurgical_plant-4.jpg",
#             "https://upload.wikimedia.org/wikipedia/commons/d/d7/The_Main_Plant_Area_of_Panzhihua_Iron_and_Steel_Company.jpg",
#             "https://upload.wikimedia.org/wikipedia/commons/f/f1/%D0%94%D0%9C%D0%97_016.jpg"
#         ],
#         "related_articles": [
#             {
#                 "title": "Arcelor Mittal",
#                 "extract": "",
#                 "url": "https://ru.wikipedia.org/wiki/Arcelor_Mittal",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/ArcelorMittal"
#                 ],
#                 "images": [],
#                 "related_articles": []
#             },
#             {
#                 "title": "Gerdau",
#                 "extract": "Gerdau — бразильская сталелитейная компания, крупнейшая в Латинской Америке. Кроме Бразилии имеет предприятия в США, Канаде, Мексике, Перу, Колумбии, Аргентине, Уругвае, Доминиканской Республике и Венесуэле, а также ведёт добычу железной руды в штате Минас-Жерайс.",
#                 "url": "https://ru.wikipedia.org/wiki/Gerdau",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/1901",
#                     "https://ru.wikipedia.org/wiki/AmBev",
#                     "https://ru.wikipedia.org/wiki/AmeriSteel",
#                     "https://ru.wikipedia.org/wiki/América_Latina_Logística",
#                     "https://ru.wikipedia.org/wiki/América_Móvil",
#                     "https://ru.wikipedia.org/wiki/Aracruz_Celulose",
#                     "https://ru.wikipedia.org/wiki/Aza",
#                     "https://ru.wikipedia.org/wiki/B2W_Varejo",
#                     "https://ru.wikipedia.org/wiki/B3_(биржа)",
#                     "https://ru.wikipedia.org/wiki/BM&F_Bovespa"
#                 ],
#                 "images": [],
#                 "related_articles": []
#             },
#             {
#                 "title": "POSCO",
#                 "extract": "POSCO (кор. 포스코 Пхосыкхо) — корейская сталелитейная компания, на 2017 год пятая крупнейшая в мире по объёму произведённой стали (42,19 млн тонн).\nВ списке крупнейших компаний мира Forbes Global 2000 за 2018 год POSCO заняла 228-е место, в том числе 141-е по выручке, 297-е по чистой прибыли, 410-е по активам и 515-е по рыночной капитализации. Журнал Fortune в списке 500 крупнейших компаний мира поместил POSCO на 184-е место.",
#                 "url": "https://ru.wikipedia.org/wiki/POSCO",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/1968",
#                     "https://ru.wikipedia.org/wiki/AU_Optronics",
#                     "https://ru.wikipedia.org/wiki/Asus",
#                     "https://ru.wikipedia.org/wiki/Bank_of_China",
#                     "https://ru.wikipedia.org/wiki/BlackRock",
#                     "https://ru.wikipedia.org/wiki/CEO",
#                     "https://ru.wikipedia.org/wiki/CLP_Group",
#                     "https://ru.wikipedia.org/wiki/CNOOC_Limited",
#                     "https://ru.wikipedia.org/wiki/Cathay_United_Bank",
#                     "https://ru.wikipedia.org/wiki/Cheung_Kong_Holdings"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/a/a9/GwangyangIronworks.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/3/32/POSCO_Center_Beijing.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/6/61/Poscotower07.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/1/1b/Poscotowernight.jpg"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Tata Steel",
#                 "extract": "Tata Steel Group — индийская сталелитейная компания, десятая крупнейшая в мире по объёму произведённой стали. Помимо производства стали компания также осуществляет добычу сырья (железной руды и угля). Основные производственные мощности находятся в Индии, Великобритании и Нидерландах. Компания входит в Tata Group.",
#                 "url": "https://ru.wikipedia.org/wiki/Tata_Steel",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/1907",
#                     "https://ru.wikipedia.org/wiki/ArcelorMittal",
#                     "https://ru.wikipedia.org/wiki/CEO",
#                     "https://ru.wikipedia.org/wiki/Corus",
#                     "https://ru.wikipedia.org/wiki/Forbes_(журнал)",
#                     "https://ru.wikipedia.org/wiki/Forbes_Global_2000",
#                     "https://ru.wikipedia.org/wiki/PricewaterhouseCoopers",
#                     "https://ru.wikipedia.org/wiki/Tata_Group",
#                     "https://ru.wikipedia.org/wiki/ThyssenKrupp",
#                     "https://ru.wikipedia.org/wiki/Активы"
#                 ],
#                 "images": [],
#                 "related_articles": []
#             },
#             {
#                 "title": "Techint",
#                 "extract": "Techint («Течинт») — аргентинский конгломерат, основанный в Милане в 1945 году итальянским промышленником Агостино Рокка. Штаб-квартира в Буэнос-Айресе (Аргентина). Группа компаний состоит из шести основных компаний в следующих сферах деятельности: машиностроение, строительство, сталь, горнодобывающей промышленности, нефтегазовой промышленности, медицинской промышленности. Компания Techint является крупнейшей сталелитейной компанией Аргентины и второй в Латинской Америке. Techint — крупнейший в мире производитель бесшовных стальных труб.",
#                 "url": "https://ru.wikipedia.org/wiki/Techint",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/1945",
#                     "https://ru.wikipedia.org/wiki/Humanitas_(company)",
#                     "https://ru.wikipedia.org/wiki/Mexican_Hylsamex",
#                     "https://ru.wikipedia.org/wiki/Techint_E&C",
#                     "https://ru.wikipedia.org/wiki/Tecpetrol",
#                     "https://ru.wikipedia.org/wiki/Tenaris",
#                     "https://ru.wikipedia.org/wiki/Tenova",
#                     "https://ru.wikipedia.org/wiki/Ternium",
#                     "https://ru.wikipedia.org/wiki/Агостино_Рокка",
#                     "https://ru.wikipedia.org/wiki/Аргентина"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/f/f7/Sede_Techint_Roma.jpg"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "U.S. Steel",
#                 "extract": "Юнайтед Стейтс Стил Корпорейшн (англ. United States Steel Corporation — U.S. Steel) — американская сталелитейная компания, вторая крупнейшая в США (после Nucor Corporation) и 26-я в мире (на 2017 год).\nВ списке крупнейших публичных компаний мира Forbes Global 2000 за 2018 год U.S. Steel заняла 1429-е место.\nВедутся переговоры о продаже японской  Nippon Steel.",
#                 "url": "https://ru.wikipedia.org/wiki/U.S._Steel",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/1901",
#                     "https://ru.wikipedia.org/wiki/1901_год",
#                     "https://ru.wikipedia.org/wiki/1950-е_годы",
#                     "https://ru.wikipedia.org/wiki/1953_год_в_кино",
#                     "https://ru.wikipedia.org/wiki/1960-е_годы",
#                     "https://ru.wikipedia.org/wiki/2002_год",
#                     "https://ru.wikipedia.org/wiki/ArcelorMittal",
#                     "https://ru.wikipedia.org/wiki/Bethlehem_Steel",
#                     "https://ru.wikipedia.org/wiki/BlackRock",
#                     "https://ru.wikipedia.org/wiki/CEO"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/2/28/PART_OF_THE_U.S._STEEL_OPERATION_AT_SUNRISE_-_NARA_-_544736.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/b/bf/Pittsburgh-pennsylvania-usx-tower.jpg"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Wayback Machine",
#                 "extract": "Wayback Machine (с англ. — «Машина времени») — бесплатный онлайн-архив некоммерческой библиотеки «Архив Интернета». С помощью поисковых роботов Wayback Machine архивирует и делает общедоступной бо́льшую часть «открытого» интернета.\nСервис был запущен в 1996 году, однако стал доступен для общественности только в 2001 году.\nЗа первые 20 лет существования Wayback Machine каталогизировал и сохранил коллекцию из более чем 286 млрд веб-страниц. Архивные снимки отображаются в формате HTML, JavaScript и CSS. Благодаря сохранённым в Wayback Machine документам пользователи могут отслеживать происходящие на сайтах изменения и сравнивать разные версии правок. По состоянию на февраль 2024 года Wayback Machine предоставляет доступ к более чем 866 миллиардам сохранённых веб-страниц.",
#                 "url": "https://ru.wikipedia.org/wiki/Wayback_Machine",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/1989_год",
#                     "https://ru.wikipedia.org/wiki/Alexa_Internet",
#                     "https://ru.wikipedia.org/wiki/Amazon",
#                     "https://ru.wikipedia.org/wiki/Bellingcat",
#                     "https://ru.wikipedia.org/wiki/COVID-19",
#                     "https://ru.wikipedia.org/wiki/CSS",
#                     "https://ru.wikipedia.org/wiki/Digital_Millennium_Copyright_Act",
#                     "https://ru.wikipedia.org/wiki/Doi",
#                     "https://ru.wikipedia.org/wiki/Forbes",
#                     "https://ru.wikipedia.org/wiki/HTML"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/b/b1/Brewster_Kahle_2009.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/d/d7/Internet_Archive_mirror_servers_-_Bibliotheca_Alexandrina.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/7/72/Wayback_Machine.png"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Австралия",
#                 "extract": "Австра́лия (англ. Australia, МФА: [əˈstreɪljə], от лат. austrālis — «южный»), официальная форма — Австрали́йский Сою́з, или Содру́жество Австра́лии (англ. Commonwealth of Australia, МФА: [ˈkɒm.ənˌwɛlθ əv əˈstreɪljə]) — государство в Южном полушарии, занимающее одноимённый материк, остров Тасмания и несколько других островов Индийского и Тихого океанов; является шестым государством по площади в мире. К северу от Австралийского Союза расположены Восточный Тимор, Индонезия и Папуа — Новая Гвинея, к северо-востоку — Вануату, Новая Каледония и Соломоновы Острова, к юго-востоку — Новая Зеландия. От главного острова Папуа — Новой Гвинеи материковая часть Австралийского Союза отделена Торресовым проливом минимальной шириной около 150 км, а расстояние от австралийского острова Боигу до Папуа — Новой Гвинеи составляет около 5 километров. Население на 30 июня 2023 года оценивалось в 26 638 544 человека, большинство из которых проживает в городах на восточном побережье.\nАвстралия является одной из самых развитых стран мира, будучи четырнадцатой по размеру экономикой в мире, и имеет девятое место в мире по ВВП в расчёте на душу населения. Военные расходы Австралии являются двенадцатыми по размеру в мире. С пятым по величине индексом человеческого развития Австралия занимает высокое место во многих сферах, таких как качество жизни, здоровье, образование, экономическая свобода, защита гражданских свобод и политических прав. Австралия является членом G20, ОЭСР, ВТО, АТЭС, ООН, Содружества наций, АНЗЮСа, АУКУСа и Форума тихоокеанских островов.",
#                 "url": "https://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%81%D1%82%D1%80%D0%B0%D0%BB%D0%B8%D1%8F",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/.au",
#                     "https://ru.wikipedia.org/wiki/11_декабря",
#                     "https://ru.wikipedia.org/wiki/1606_год",
#                     "https://ru.wikipedia.org/wiki/1625_год",
#                     "https://ru.wikipedia.org/wiki/1769_год",
#                     "https://ru.wikipedia.org/wiki/1780_год",
#                     "https://ru.wikipedia.org/wiki/1788_год",
#                     "https://ru.wikipedia.org/wiki/1814_год",
#                     "https://ru.wikipedia.org/wiki/1820-е",
#                     "https://ru.wikipedia.org/wiki/1825_год"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/0/09/A_view_from_Cliff_View_lookout_in_Nellie%27s_Glenn_area.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/4/46/Aboriginal_Art_Australia.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/b/b4/Anzac2.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/9/94/Au_maslenitsa.JPG",
#                     "https://upload.wikimedia.org/wikipedia/commons/5/5e/Australia_Day.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/a/aa/Australia_discoveries_by_Europeans_before_1813_en.png",
#                     "https://upload.wikimedia.org/wikipedia/commons/e/ed/Australia_satellite_plane.jpg",
#                     "https://upload.wikimedia.org/wikipedia/ru/3/37/Australian_agricultural_map_ru.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/2/28/Australianflagatnewport.JPG",
#                     "https://upload.wikimedia.org/wikipedia/commons/1/1a/Brisbane_skyline_and_Brisbane_River%2C_February_2014.jpeg",
#                     "https://upload.wikimedia.org/wikipedia/commons/3/39/Endeavour_replica_in_Cooktown_harbour.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/f/f1/View_of_Port_Jackson%2C_taken_from_the_South_Head_from_A_Voyage_to_Terra_Australis_%281814%29_by_Matthew_Flinders.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/8/8d/Kalgoorlie_The_Big_Pit_DSC04498.JPG",
#                     "https://upload.wikimedia.org/wikipedia/commons/4/49/Koala_climbing_tree.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/9/9e/Macropus_giganteus_-_Brunkerville.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/6/6c/Port_Arthur_Seeseite.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/9/90/Thevenot_-_Hollandia_Nova_detecta_1644.png",
#                     "https://upload.wikimedia.org/wikipedia/commons/f/f1/View_of_Port_Jackson%2C_taken_from_the_South_Head_from_A_Voyage_to_Terra_Australis_%281814%29_by_Matthew_Flinders.jpg"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Агломерат (металлургия)",
#                 "extract": "Агломера́т — окускованный рудный концентрат, полученный в процессе агломерации. Спёкшаяся в куски мелкая (часто пылевидная) руда размерами 5—100 мм с незначительным содержанием мелочи. Агломерат получают при обжиге железных и свинцовых руд, цинковых концентратов и других. В чёрной металлургии является основным железорудным сырьём для получения чугуна в доменной печи.",
#                 "url": "https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%BB%D0%BE%D0%BC%D0%B5%D1%80%D0%B0%D1%82_(%D0%BC%D0%B5%D1%82%D0%B0%D0%BB%D0%BB%D1%83%D1%80%D0%B3%D0%B8%D1%8F)",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/Агломерат",
#                     "https://ru.wikipedia.org/wiki/Агломерационная_машина",
#                     "https://ru.wikipedia.org/wiki/Агломерационная_фабрика",
#                     "https://ru.wikipedia.org/wiki/Агломерация_(металлургия)",
#                     "https://ru.wikipedia.org/wiki/Антрацит",
#                     "https://ru.wikipedia.org/wiki/Барий",
#                     "https://ru.wikipedia.org/wiki/Бессемеровский_процесс",
#                     "https://ru.wikipedia.org/wiki/Блюминг_(стан)",
#                     "https://ru.wikipedia.org/wiki/Большая_советская_энциклопедия",
#                     "https://ru.wikipedia.org/wiki/Брикет_(металлургия)"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/6/60/Agglom%C3%A9r%C3%A9_de_minerai_de_fer_3.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/f/f8/Fotothek_df_n-08_0000320.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/b/b9/%D0%9E%D1%85%D0%BB%D0%B0%D0%B6%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B0%D0%B3%D0%BB%D0%BE%D0%BC%D0%B5%D1%80%D0%B0%D1%82%D0%B0.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/a/a9/%D0%A1%D1%85%D0%BE%D0%B4_%D0%BF%D0%B8%D1%80%D0%BE%D0%B3%D0%B0_%D1%81_%D0%B0%D0%B3%D0%BB%D0%BE%D0%BC%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D1%85_%D1%82%D0%B5%D0%BB%D0%B5%D0%B6%D0%B5%D0%BA.jpg"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Агломерационная машина",
#                 "extract": "Агломерацио́нная маши́на (агломаши́на) — машина, предназначенная для получения агломерата путём спекания рудной мелочи и концентратов методом прососа воздуха через слой шихты, лежащей на колосниковой решётке, с частичным освобождением шихты от вредных примесей.",
#                 "url": "https://ru.wikipedia.org/wiki/%D0%90%D0%B3%D0%BB%D0%BE%D0%BC%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%B0",
#                 "links": [
#                     "https://ru.wikipedia.org/wiki/Агломерат_(металлургия)",
#                     "https://ru.wikipedia.org/wiki/Агломерационная_фабрика",
#                     "https://ru.wikipedia.org/wiki/Агломерация_(металлургия)",
#                     "https://ru.wikipedia.org/wiki/Бессемеровский_процесс",
#                     "https://ru.wikipedia.org/wiki/Блюминг_(стан)",
#                     "https://ru.wikipedia.org/wiki/Брикет_(металлургия)",
#                     "https://ru.wikipedia.org/wiki/Брикетный_пресс",
#                     "https://ru.wikipedia.org/wiki/Вакууматор",
#                     "https://ru.wikipedia.org/wiki/Вакуумная_камера",
#                     "https://ru.wikipedia.org/wiki/Внепечная_обработка_стали"
#                 ],
#                 "images": [
#                     "https://upload.wikimedia.org/wikipedia/commons/e/ef/Factory_and_industrial_management_%281891%29_%2814594947629%29.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/f/f8/Fotothek_df_n-08_0000320.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/b/bf/Sinter_plant_1.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/7/79/Sinter_plant_2.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/b/b1/Sinter_plant_3.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/e/ee/Sinter_plant_5.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/f/f5/Sinter_plant_6.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/3/3c/Sinter_plant_7.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/9/9d/%D0%93%D0%BE%D1%80%D0%BD_%D0%B0%D0%B3%D0%BB%D0%BE%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D1%8B.jpg",
#                     "https://upload.wikimedia.org/wikipedia/commons/a/a9/%D0%A1%D1%85%D0%BE%D0%B4_%D0%BF%D0%B8%D1%80%D0%BE%D0%B3%D0%B0_%D1%81_%D0%B0%D0%B3%D0%BB%D0%BE%D0%BC%D0%B5%D1%80%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D1%85_%D1%82%D0%B5%D0%BB%D0%B5%D0%B6%D0%B5%D0%BA.jpg"
#                 ],
#                 "related_articles": []
#             }
#         ]
#     },
#     "wikidata": {
#         "title": "чёрная металлургия",
#         "description": "отрасль тяжёлой промышленности",
#         "url": "https://www.wikidata.org/wiki/Q2285982",
#         "images": [],
#         "related_entities": [
#             {
#                 "title": "отрасль экономики",
#                 "description": "Описание не найдено",
#                 "url": "https://www.wikidata.org/wiki/Q268592",
#                 "images": [
#                     "https://commons.wikimedia.org/wiki/Special:FilePath/Aba_Leather_Market.jpg"
#                 ],
#                 "related_entities": []
#             },
#             {
#                 "title": "тяжёлая промышленность",
#                 "description": "промышленность, требующая больших капитальных вложений для начала производства",
#                 "url": "https://www.wikidata.org/wiki/Q622662",
#                 "images": [],
#                 "related_entities": []
#             },
#             {
#                 "title": "Категория:Чёрная металлургия",
#                 "description": "категория в проекте Викимедиа",
#                 "url": "https://www.wikidata.org/wiki/Q9261374",
#                 "images": [],
#                 "related_entities": []
#             },
#             {
#                 "title": "история производства и использования железа",
#                 "description": "Описание не найдено",
#                 "url": "https://www.wikidata.org/wiki/Q983246",
#                 "images": [],
#                 "related_entities": []
#             },
#             {
#                 "title": "металлургия",
#                 "description": "область науки и техники о получении металлов",
#                 "url": "https://www.wikidata.org/wiki/Q11467",
#                 "images": [
#                     "https://commons.wikimedia.org/wiki/Special:FilePath/VysokePece1.jpg"
#                 ],
#                 "related_entities": []
#             },
#             {
#                 "title": "Большая советская энциклопедия, 1926—1947",
#                 "description": "первое издание Большой советской энциклопедии",
#                 "url": "https://www.wikidata.org/wiki/Q20078554",
#                 "images": [],
#                 "related_entities": []
#             },
#             {
#                 "title": "Британская энциклопедия, 1910—1911",
#                 "description": "11-е издание «Британской энциклопедии»",
#                 "url": "https://www.wikidata.org/wiki/Q867541",
#                 "images": [
#                     "https://commons.wikimedia.org/wiki/Special:FilePath/Encyclopaedia_Britannica_1911.svg"
#                 ],
#                 "related_entities": []
#             },
#             {
#                 "title": "New International Encyclopedia",
#                 "description": "Американская энциклопедия, впервые изданная в 1902 году",
#                 "url": "https://www.wikidata.org/wiki/Q1029706",
#                 "images": [
#                     "https://commons.wikimedia.org/wiki/Special:FilePath/NIEdot088.jpg",
#                     "https://commons.wikimedia.org/wiki/Special:FilePath/NIEdot_138.jpg",
#                     "https://commons.wikimedia.org/wiki/Special:FilePath/NIEdot369.jpg"
#                 ],
#                 "related_entities": []
#             },
#             {
#                 "title": "Название не найдено",
#                 "description": "Описание не найдено",
#                 "url": "https://www.wikidata.org/wiki/Q110249806",
#                 "images": [],
#                 "related_entities": []
#             }
#         ]
#     },
#     "wiktionary": {
#         "title": "чёрная металлургия",
#         "extract": {
#             "значение": [
#                 "# [[отрасль]] [[металлургия|металлургии]], занимающаяся производством стали и её сплавов {{пример|}}",
#                 ""
#             ],
#             "синонимы": [
#                 "#",
#                 ""
#             ],
#             "антонимы": [
#                 "# [[цветная металлургия]]",
#                 ""
#             ],
#             "гиперонимы": [
#                 "# [[металлургия]]"
#             ],
#             "гипонимы": []
#         },
#         "url": "https://ru.wiktionary.org/wiki/чёрная_металлургия",
#         "links": [
#             "https://ru.wiktionary.org/wiki/коксохимическая_промышленность",
#             "https://ru.wiktionary.org/wiki/металлургия",
#             "https://ru.wiktionary.org/wiki/отрасль",
#             "https://ru.wiktionary.org/wiki/сталелитейное_производство",
#             "https://ru.wiktionary.org/wiki/термин",
#             "https://ru.wiktionary.org/wiki/цветная_металлургия",
#             "https://ru.wiktionary.org/wiki/чёрный",
#             "https://ru.wiktionary.org/wiki/Викисловарь:Справка",
#             "https://ru.wiktionary.org/wiki/Викисловарь:ЦИТ",
#             "https://ru.wiktionary.org/wiki/Справка:МФА_для_русского_языка"
#         ],
#         "related_articles": [
#             {
#                 "error": "Статья 'коксохимическая промышленность' не найдена в Викисловаре."
#             },
#             {
#                 "title": "металлургия",
#                 "extract": {
#                     "значение": [
#                         "# [[отрасль]] тяжёлой промышленности, связанная с добычей металлов из руды и их первичной обработкой {{пример|}}",
#                         "научная или учебная [[дисциплина]], изучающая промышленные способы производства и первичной обработки металлов {{пример|}}"
#                     ],
#                     "синонимы": [
#                         "#",
#                         ""
#                     ],
#                     "антонимы": [
#                         "# —",
#                         "—"
#                     ],
#                     "гиперонимы": [
#                         "# [[отрасль]]",
#                         "[[дисциплина]], [[наука]]"
#                     ],
#                     "гипонимы": []
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/металлургия",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/-ουργός",
#                     "https://ru.wiktionary.org/wiki/-иj",
#                     "https://ru.wiktionary.org/wiki/-ург",
#                     "https://ru.wiktionary.org/wiki/Hüttenindustrie",
#                     "https://ru.wiktionary.org/wiki/Hüttenwesen",
#                     "https://ru.wiktionary.org/wiki/Metallurgie",
#                     "https://ru.wiktionary.org/wiki/fémkohászat",
#                     "https://ru.wiktionary.org/wiki/hutnictví",
#                     "https://ru.wiktionary.org/wiki/hutnictwo",
#                     "https://ru.wiktionary.org/wiki/metalaalkunde"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "отрасль",
#                 "extract": {
#                     "значение": [
#                         "# отдельная [[область]] науки, знаний, производства и т. п. {{пример|Ведь рыбная {{выдел|отрасль}} занимает третью часть экономики Приморья.|Даниил Володин|Рыбакам надоело правительство|издание=\"Ежедневные новости\" (Владивосток)|2003|источник=НКРЯ}} {{пример|Бенкендорф, указывает Волконский, полагал, что на честных началах было бы полезно и для царя, и для отечества учредить {{выдел|отрасль}} соглядатаев, то есть честную тайную политическую полицию.|Юрий Давыдов|Синие тюльпаны|1989|источник=НКРЯ}}",
#                         "{{устар.|ru}} молодой [[побег]] растения {{пример|Так говорит Господь Бог: и возьму Я с вершины высокого кедра, и посажу; с верхних побегов его оторву нежную {{выдел|отрасль}} и посажу на высокой и величественной горе.|Библия, Книга пророка Иезекииля 17:22, синодальный перевод}}",
#                         "{{устар.|ru}} [[потомок]], [[потомство]] {{пример|Старик в самом деле горячо любил сына, единственную {{выдел|отрасль}} своей фамилии, портрет покойной жены, о которой часто вспоминал с сожалением.|Н. Мамышев|Злосчастный|1807|источник=НКРЯ}}",
#                         "{{устар.|ru}} разветвление, [[отрог]] (горного хребта) {{пример|{{выдел|Отрасль}} эта, под именем Сарванского хребта, тянется между Индегскими и Сарванскими озерами…|Александер Густав вон Щренск|Путешествие к сѣверо-востоку европейской Россіи|1855}}",
#                         ""
#                     ],
#                     "синонимы": [
#                         "# —",
#                         "[[отросток]]"
#                     ],
#                     "антонимы": [
#                         "# —",
#                         "—"
#                     ],
#                     "гиперонимы": [
#                         "# [[область]], [[отделение]]",
#                         ""
#                     ],
#                     "гипонимы": []
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/отрасль",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/-ль",
#                     "https://ru.wiktionary.org/wiki/affärsgren",
#                     "https://ru.wiktionary.org/wiki/branca",
#                     "https://ru.wiktionary.org/wiki/branch",
#                     "https://ru.wiktionary.org/wiki/bransch",
#                     "https://ru.wiktionary.org/wiki/branĉo",
#                     "https://ru.wiktionary.org/wiki/field",
#                     "https://ru.wiktionary.org/wiki/område",
#                     "https://ru.wiktionary.org/wiki/ramo",
#                     "https://ru.wiktionary.org/wiki/sector"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "error": "Статья 'сталелитейное производство' не найдена в Викисловаре."
#             },
#             {
#                 "title": "термин",
#                 "extract": {
#                     "значение": [
#                         "# {{лингв.|ru}} [[слово]] или [[словосочетание]], призванное [[точно]] [[обозначить]] [[понятие]] и его [[соотношение]] с другими понятиями в пределах [[специальный|специальной]] [[сфера|сферы]] {{пример|Такое описание состоит из {{выдел|терминов}} и правил использования этих {{выдел|терминов}}, ограничивающих их значения в рамках предметной области.|С. Г. Керимов|Интеллектуальный поиск информации, основанный на онтологии|2004|издание=Информационные технологии|источник=НКРЯ}}",
#                         ""
#                     ],
#                     "синонимы": [
#                         "# [[определение]], [[понятие]]",
#                         ""
#                     ],
#                     "антонимы": [
#                         "# —",
#                         ""
#                     ],
#                     "гиперонимы": [
#                         "# [[выражение]], [[лексема]], [[вокабула]]",
#                         ""
#                     ],
#                     "гипонимы": [
#                         "# ?",
#                         "=== Родственные слова ===\n{{родств-блок\n|умласк=\n|имена-собственные=\n|существительные=терминология\n|прилагательные=терминологический\n|глаголы=\n|наречия=\n|полн=термин\n}}\n\n=== Этимология ===\nПроисходит от {{этимология:термин|да}}\n\n=== Фразеологизмы и устойчивые сочетания ===\n* \n\n=== Перевод ===\n{{перев-блок|\n|abq=\n|ab=\n|av=\n|ave=\n|agh=\n|aja=\n|ady=\n|az=\n|ay=\n|ain=\n|ain.kana=\n|ain.lat=\n|sq=\n|als=\n|ale=\n|alt=\n|en=[[term]]\n|ar=\n|an=\n|arc.jud=\n|arc.syr=\n|arn=\n|hy=\n|asm=\n|ast=\n|af=\n|bar=\n|bm=\n|eu=\n|ba=\n|be=\n|bn=\n|bg=[[термин]]\n|bs=\n|br=\n|bua=\n|cy=\n|wa=\n|hu=\n|vep=\n|hsb=\n|vot=\n|vo=\n|wo=\n|vro=\n|vi=\n|gag=\n|haw=\n|ht=\n|gl=\n|ze=\n|kl=\n|el=\n|ka=\n|gn=\n|gu=\n|gd=\n|dar=\n|prs=\n|da=\n|dv=\n|ang=\n|grc=\n|bat-smg=\n|zza=\n|zu=\n|he=\n|yi=\n|io=\n|id=\n|ia=\n|iu=\n|ik=\n|ga=\n|is=\n|es=\n|it=\n|kbd=\n|kk=\n|xal=\n|kn=\n|kaa=\n|krc=\n|krl=\n|ca=\n|csb=\n|qu=\n|ky=\n|zh=\n|zh-tw=\n|zh-cn=\n|kom=\n|koi=\n|kok=\n|kw=\n|ko=\n|co=\n|xh=\n|crh=\n|ku=\n|km=\n|lad=\n|lo=\n|la=\n|lez=\n|lv=\n|li=\n|ln=\n|lt=\n|lb=\n|mk=\n|mg=\n|ms=\n|ml=\n|mt=\n|mi=\n|chm=\n|mdf=\n|mo=\n|mn=\n|gv=\n|nv=\n|gld=\n|nah=\n|na=\n|nio=\n|nap=\n|de=[[Fachbegriff]] {{m}} -(e)s, -e\n|yrk=\n|nl=\n|dsb=\n|no=\n|oc=\n|os=\n|pa=\n|pap=\n|fa=\n|pl=\n|pt=\n|ps=\n|pms=\n|rap=\n|rm=\n|ro=\n|sjd=\n|sa=\n|sc=\n|se=\n|sr=\n|sr-l=\n|scn=\n|sk=\n|sl=\n|slovio-c=\n|slovio-l=\n|so=\n|chu.cyr=\n|chu.glag=\n|sw=\n|tab=\n|tl=\n|tg=\n|ty=\n|th=\n|ta=\n|tt=\n|tt.cyr=\n|tt.lat=\n|te=\n|art=\n|tpi=\n|kim=\n|tn=\n|tyv=\n|tr=\n|tk=\n|udm=\n|ug=\n|uz=\n|uk=[[термін]] {{m}}\n|ur=\n|fo=\n|fi=\n|fr=[[terme]] {{m}}\n|fy=\n|fur=\n|kjh=\n|ha=\n|hi=\n|hr=\n|rom=\n|ce=\n|cs=\n|cv=\n|sv=\n|cjs=\n|sco=\n|ewe=\n|myv=\n|eo=\n|et=\n|jv=\n|sah=\n|ja=\n}}\n\n=== Библиография ===\n* {{книга|автор=Зарва М. В.|заглавие=Русское словесное ударение|издательство=ЭНАС|место=М.|год=2001|isbn=5-93196-084-8|страницы=508|ссылка=http://www.gramota.ru/slovari/dic/?zar=x&word=термин|ref=Зарва, 2001}}\n\n<!-- Служебное: -->\n{{improve|ru|}}\n{{Категория|язык=ru|Лексика|}}\n{{длина слова|6|ru}}\n= {{-ce-}} =\n\n=== Морфологические и синтаксические свойства ===\n{{сущ ce |слоги=|основа=|основа1=}}\n\n{{морфо|прист1=|корень1=|суфф1=|оконч=}}\n\n=== Произношение ===\n{{transcriptions|||}}\n\n=== Семантические свойства ===\n{{илл|lang=ce|}}"
#                     ]
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/термин",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/*ter-",
#                     "https://ru.wiktionary.org/wiki/Fachbegriff",
#                     "https://ru.wiktionary.org/wiki/term",
#                     "https://ru.wiktionary.org/wiki/terme",
#                     "https://ru.wiktionary.org/wiki/termin",
#                     "https://ru.wiktionary.org/wiki/terminus",
#                     "https://ru.wiktionary.org/wiki/Термин",
#                     "https://ru.wiktionary.org/wiki/английский",
#                     "https://ru.wiktionary.org/wiki/болгарский",
#                     "https://ru.wiktionary.org/wiki/винительный"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "error": "Статья 'цветная металлургия' не найдена в Викисловаре."
#             },
#             {
#                 "title": "чёрный",
#                 "extract": {
#                     "значение": [
#                         "# [[ахроматический]] [[оттенок]], отсутствие светового потока от объекта; имеющий [[предельно]] [[тёмный]], без [[оттенок|оттенков]], [[цвет]] {{семантика\n|синонимы=пречёрный, \n|частичные синонимы=агатовый, антрацитовый, аспидный, вороной, гагатовый, жуковый, смоляной, траурный, угольный, эбеновый\n|антонимы=белый\n|частичные антонимы=\n|гиперонимы=цвет\n|гипонимы=аспидно-чёрный, бархатно-чёрный, бело-чёрный, блестяще-чёрный, глянцево-чёрный, густо-чёрный, дегтярно-чёрный, жгуче-чёрный, землисто-чёрный, иссиза-чёрный, иссиня-чёрный, лаково-чёрный, лилово-чёрный, матово-чёрный, свинцово-чёрный, серебристо-чёрный, угольно-чёрный\n|согипонимы=\n|холонимы=\n|меронимы=\n}} {{пример|{{выдел|Чёрный}} цвет.}}",
#                         "{{перен.|ru}} [[мрачный]], [[жуткий]], [[траурный]], [[неприятный]] {{семантика|синонимы=мрачный, жуткий, [[траурный]]|антонимы=—|гиперонимы=неприятный|гипонимы=—}} {{пример|Для нас настали {{выдел|чёрные}} дни.}} {{пример|Он описывает случившееся в самых {{выдел|чёрных}} тонах.}}",
#                         "{{субстантивир.|ru}} {{t:=|негр}} {{семантика|синонимы=[[негр]], [[чернокожий]]; {{помета|частичн.}}: [[африканец]]; {{груб.|-}} [[черномазый]]; {{бранн.|-}} [[черножопый]]|антонимы=[[белый]]|гиперонимы=[[человек]], [[цветной]]|гипонимы=[[афроамериканец]], [[банту]], [[бушмен]], [[зулус]], [[масай]]}} {{пример|Старый бродяга в Аддис-Абебе, // Покоривший многие племена, // Прислал ко мне {{выдел|чёрного}} копьеносца // С приветом, составленным из моих стихов.|[[w:Гумилёв, Николай Степанович|Н. С. Гумилёв]]|[[s:Мои читатели (Гумилёв)|Мои читатели]]|1921|источник=Викитека}}",
#                         "{{помета|{{тж.}} {{субстантивир.|ru}}}} имеющий тёмный цвет кожи {{семантика|синонимы=темнокожий|антонимы=—|гиперонимы=|гипонимы=[[загорелый]], чернокожий}} {{пример|Остальные братья в мать, мать была крупная женщина, и братья высоченные{{-}}за сто восемьдесят сантиметров, костлявые, {{выдел|чёрные}}, как цыгане…|Анатолий Рыбаков|Тяжёлый песок|дата=1975–1977 гг.|источник=НКРЯ}}",
#                         "{{субстантивир.|ru}}, {{груб.|ru}} {{t:=|лицо кавказской национальности}} {{семантика|синонимы={{помета|частичн.}}: [[кавказец]]; {{груб.|-}} [[зверёк]]; {{разг.|-}}, {{шутл.|-}}: [[загорелый]]|антонимы=—|гиперонимы=[[человек]]|гипонимы=[[абхазец]], [[азербайджанец]], [[армянин]], [[грузин]], [[дагестанец]], [[чеченец]]}} {{пример|{{выдел|Чёрным}} на рынке меня не отдадут.|В. И. Старовойтов|Новогодняя рапсодия}}",
#                         "{{помета|о [[хлеб]]е}}: [[ржаной]] {{семантика|синонимы=ржаной|антонимы=[[белый]]|гиперонимы=|гипонимы=—}} {{пример|Зайчатину наре́зать на порции, посолить, поперчить, обвалять в муке и выложить в горшок, чередуя мясо с ломтиками свиного жира, рубленым луком и кусочками {{выдел|чёрного}} хлеба.||титул без кавычек=1|Рецепты национальных кухонь: Германия|дата=2000–2005 гг.|источник=НКРЯ}}",
#                         "{{субстантивир.|ru}}, {{мн.}} [[сторона]] в некоторых настольных играх, таких как [[шахматы]], [[шашки]], «[[Мафия]]» и пр {{семантика|синонимы=—|антонимы=[[белый|белые]], реже – [[красный|красные]]|гиперонимы=—|гипонимы=—}} {{пример|На взятие следует мат в два хода, поэтому {{выдел|чёрные}} сдались.|Дармен Садвакасов|Изучил сто, сыграл восемь||64{{-}}Шахматное обозрение|15 ноября 2004|источник=НКРЯ}}",
#                         "{{перен.|ru}} [[нелегальный]]; [[противозаконный]] {{семантика|синонимы=[[нелегальный]]; [[противозаконный]], тёмный|антонимы=—|гиперонимы=незаконный|гипонимы=теневой}} {{пример|{{выдел|Чёрный}} рынок.}} {{пример|{{выдел|Чёрный}} нал.}}",
#                         "{{перен.|ru}} [[предосудительный]], не вызывающий одобрения, основанный на негативной информации {{семантика|синонимы=—|антонимы=—|гиперонимы=предосудительный|гипонимы=—}} {{пример|{{выдел|Чёрные}} предвыборные технологии оказались единственным сюжетом, устойчиво работающим в обстоятельствах новой России: пьеса была написана несколько лет назад, но по-прежнему смотрится очень свежо.|Алексей Филиппов|Продавцы воздуха|уточнение титула=Производственная тема-2002 в Новом драматическом театре||Известия|23 сентября 2002|источник=НКРЯ}}",
#                         "{{разг.|ru}} [[черноволосый]]; [[темноволосый]] {{семантика|синонимы=темноволосый|антонимы=—|гиперонимы=брюнет|гипонимы=черноволосый}} {{пример|За ней приехал высокий {{выдел|чёрный}} парень, и они вместе куда-то испарились.|Виктория Токарева|Своя правда||Новый Мир|уточнение издания=№ 9|2002|источник=НКРЯ}}",
#                         "имеющий болезненный, утомлённый вид {{семантика|синонимы=утомлённый|антонимы=свежий, бодрый|гиперонимы=плохо выглядящий|гипонимы=—}} {{пример|Потом он выползал весь {{выдел|чёрный}}, брёл домой, там ещё сколько-то приходил в себя и являлся опять в больницу, становясь опять блистательным хирургом.|Алексей Слаповский|Гибель гитариста|дата=1994–1995 гг.|источник=НКРЯ}} {{пример|Об испытательных площадках и говорить нечего{{-}}там был сущий ад, и всё-таки изнурённо и упрямо работали {{выдел|чёрные}}, на себя непохожие офицеры и солдаты.|автор=И. Грекова|титул=На испытаниях|дата=1967|источник=НКРЯ}}",
#                         "{{устар.|ru}} {{помета|о строении}} [[курной]], отапливаемый [[печь]]ю без трубы {{семантика|синонимы=курной|антонимы=белый|гиперонимы=отапливаемый|гипонимы=—}} {{пример|{{выдел|Чёрная}} изба.}} {{пример|{{выдел|Чёрная}} баня.}}",
#                         "{{металл.|ru}} {{помета|о металлах и сплавах, металлургии}} [[имеющий]] в основе [[железо]] {{семантика|синонимы=—|антонимы=[[цветной]]|гиперонимы=металлический|гипонимы=—}} {{пример|Основу экспорта составляют {{выдел|чёрные}} металлы и изделия из них, лесоматериалы, грузовые автомобили.|автор=Марина Ленская|титул=Приглашаем в Забайкалье!|издание=Вечерняя Москва|перев=|дата=2002.06.13|источник=НКРЯ}}\n\n{{списки семантических связей}}\n\n=== Родственные слова ===\n\n{{родств-блок\n|умласк=\n|имена-собственные=\n|фамилии=Чёрный\n|топонимы=Чёрный\n|существительные=чернь, чернуха, чёрность\n|прилагательные=черноватый, чёрненький\n|числительные=\n|глаголы=чернить\n|наречия=черно\n|полн=черн\n}}\n\n=== Этимология ===\n\nИз {{этимология:чёрный|да}}\n\n=== Фразеологизмы и устойчивые сочетания ===\n{{Фразеологизмы|\n* абсолютно чёрное тело\n* бузина чёрная\n* в чёрных тонах\n* водяника чёрная\n* держать в чёрном теле\n* играть чёрными\n* красное и чёрное\n* пальмовый какаду чёрный\n* подберёзовик чёрный\n* полоз чёрный\n* чёрная агитка\n* чёрная берёза\n* чёрная вдова\n* чёрная ворона\n* чёрная доска\n* чёрная дыра\n* чёрная икра\n* чёрная касса\n* чёрная комедия\n* чёрная кошка пробежала\n** чёрная кошка проскочила\n* чёрная крыса\n* чёрная кухарка\n* чёрная лестница\n* чёрная магия\n* чёрная металлургия\n* чёрная метка\n* чёрная немочь\n* чёрная ольха\n* чёрная оспа\n* чёрная пятница\n* чёрная работа\n* чёрная редька\n* чёрная смородина\n* чёрная сотня\n* чёрная суббота\n* чёрное дерево\n* чёрное духовенство\n* чёрное золото\n* Чёрное море\n* чёрное слово\n* чёрные береты\n* чёрные корабли\n* чёрные лесорубы\n* чёрные люди\n** чёрные тяглые люди\n* чёрные полковники\n* чёрный аист\n* чёрный буфер\n* чёрный ворон\n* чёрный вторник\n* чёрный глаз\n* чёрный день\n** на чёрный день\n** про чёрный день\n* чёрный дрозд\n* чёрный дятел\n* чёрный интернационал\n* чёрный как смоль\n* чёрный карлик\n* чёрный колобус\n* Чёрный континент\n* чёрный конь\n* чёрный корм\n* чёрный кофе\n* чёрный лебедь\n* Чёрный Лебедь\n* чёрный лес\n* чёрный маг\n* чёрный металл\n* чёрный нал\n* чёрный носорог\n* чёрный паслён\n* чёрный перец\n* чёрный пиар\n* чёрная проверка\n* чёрный рейхсвер\n* чёрный риелтор\n** черный риэлтор\n* чёрный роман\n* чёрный рынок\n* чёрный скворец\n* чёрный список\n* чёрный феминизм\n* чёрный хлеб\n* чёрный ход\n* чёрный чай\n* чёрный чемодан\n* чёрный шар\n* чёрный юмор\n* чёрный ящик\n* чёрным по белому\n}}"
#                     ],
#                     "синонимы": [],
#                     "антонимы": [],
#                     "гиперонимы": [],
#                     "гипонимы": []
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/чёрный",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/*čьrnъ",
#                     "https://ru.wiktionary.org/wiki/-eusi",
#                     "https://ru.wiktionary.org/wiki/-mnyama",
#                     "https://ru.wiktionary.org/wiki/aberkan",
#                     "https://ru.wiktionary.org/wiki/aláwò̩_dúdú_bò̩lò̩jò̩",
#                     "https://ru.wiktionary.org/wiki/andeket",
#                     "https://ru.wiktionary.org/wiki/baƙi",
#                     "https://ru.wiktionary.org/wiki/beltz",
#                     "https://ru.wiktionary.org/wiki/black",
#                     "https://ru.wiktionary.org/wiki/blak"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Викисловарь:Справка",
#                 "extract": {
#                     "значение": [],
#                     "синонимы": [],
#                     "антонимы": [],
#                     "гиперонимы": [],
#                     "гипонимы": []
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/Викисловарь:Справка",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/name",
#                     "https://ru.wiktionary.org/wiki/tram",
#                     "https://ru.wiktionary.org/wiki/Викисловарь",
#                     "https://ru.wiktionary.org/wiki/Мир",
#                     "https://ru.wiktionary.org/wiki/ООО",
#                     "https://ru.wiktionary.org/wiki/вода",
#                     "https://ru.wiktionary.org/wiki/коса",
#                     "https://ru.wiktionary.org/wiki/мир",
#                     "https://ru.wiktionary.org/wiki/морфема",
#                     "https://ru.wiktionary.org/wiki/фразеологизм"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Викисловарь:ЦИТ",
#                 "extract": {
#                     "значение": [],
#                     "синонимы": [],
#                     "антонимы": [],
#                     "гиперонимы": [],
#                     "гипонимы": []
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/Викисловарь:ЦИТ",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/Викисловарь:Примеры_словоупотребления"
#                 ],
#                 "related_articles": []
#             },
#             {
#                 "title": "Справка:МФА для русского языка",
#                 "extract": {
#                     "значение": [],
#                     "синонимы": [],
#                     "антонимы": [],
#                     "гиперонимы": [],
#                     "гипонимы": []
#                 },
#                 "url": "https://ru.wiktionary.org/wiki/Справка:МФА_для_русского_языка",
#                 "links": [
#                     "https://ru.wiktionary.org/wiki/Бог",
#                     "https://ru.wiktionary.org/wiki/алчба",
#                     "https://ru.wiktionary.org/wiki/бить",
#                     "https://ru.wiktionary.org/wiki/бог",
#                     "https://ru.wiktionary.org/wiki/бодрый",
#                     "https://ru.wiktionary.org/wiki/быть",
#                     "https://ru.wiktionary.org/wiki/взять",
#                     "https://ru.wiktionary.org/wiki/вожжи",
#                     "https://ru.wiktionary.org/wiki/все",
#                     "https://ru.wiktionary.org/wiki/вы"
#                 ],
#                 "related_articles": []
#             }
#         ]
#     },
#     "commons": {
#         "title": "Чёрная металлургия",
#         "images": [
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (6).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(6).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (6).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 17.png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_17.png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 17.png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (7).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(7).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (7).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (1).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(1).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (1).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (5).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(5).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (5).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (4).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(4).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (4).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (2).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(2).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (2).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Известия высших учебных заведений. Черная металлургия. 1998, выпуск 12 (3).png",
#                 "url": "https://commons.wikimedia.org/wiki/File:Известия_высших_учебных_заведений._Черная_металлургия._1998,_выпуск_12_(3).png",
#                 "description": "DescriptionИзвестия высших учебных заведений. <span class=\"searchmatch\">Черная</span> <span class=\"searchmatch\">металлургия</span>. 1998, выпуск 12 (3).png English: Physical chemistry and theory of metallurgical processes"
#             },
#             {
#                 "title": "File:Металлургия Волжской Булгарии 13-14 века.JPG",
#                 "url": "https://commons.wikimedia.org/wiki/File:Металлургия_Волжской_Булгарии_13-14_века.JPG",
#                 "description": "Description<span class=\"searchmatch\">Металлургия</span> Волжской Булгарии 13-14 века.JPG Русский: Ведущую отрасль ремесла Волжской Булгарии пред-ставляла собой <span class=\"searchmatch\">черная</span> <span class=\"searchmatch\">металлургия</span> и обработка"
#             },
#             {
#                 "title": "File:Begoña Echevarria Erakusketa Euskal Museoa 2018 07.jpg",
#                 "url": "https://commons.wikimedia.org/wiki/File:Begoña_Echevarria_Erakusketa_Euskal_Museoa_2018_07.jpg",
#                 "description": "I, the copyright holder of this work, hereby publish it under the following license: This file is licensed under the Creative Commons Attribution-Share"
#             }
#         ]
#     }
# }
