# %%
import folium
import pandas as pd
from geopy.geocoders import Nominatim
import requests
from bs4 import BeautifulSoup
import re
import random

# %%
def get_district_links():
    url = "https://domokucha.info/moscow_metro_district.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    containers = soup.find_all('div', class_='container')

    district_links = []
    for container in containers:
        section = container.find('section')
        if section:
          links = section.find_all('a', href=True)
          for link in links:
              href = link['href']
              district_links.append(url.rsplit('/', 1)[0] + '/' + href)

    return district_links

# %%
district_links = get_district_links()
district_links
# Out:
# ['https://domokucha.info/./moscow_metro_01_VAO.html',
#  'https://domokucha.info/./moscow_metro_02_ZAO.html',
#  'https://domokucha.info/./moscow_metro_03_SAO.html',
#  'https://domokucha.info/./moscow_metro_04_SZAO.html',
#  'https://domokucha.info/./moscow_metro_05_SVAO.html',
#  'https://domokucha.info/./moscow_metro_06_CAO.html',
#  'https://domokucha.info/./moscow_metro_07_UVAO.html',
#  'https://domokucha.info/./moscow_metro_08_UZAO.html',
#  'https://domokucha.info/./moscow_metro_09_UAO.html',
#  'https://domokucha.info/./moscow_metro_10_Zelenograd.html',
#  'https://domokucha.info/./moscow_metro_11_New-moscow.html',
#  'https://domokucha.info/./moscow_metro_12_Troicky.html']

# %%
def parse_district_page(url):
    response = requests.get(url)
    response.encoding = 'utf-8'
    soup = BeautifulSoup(response.text, 'html.parser')

    main = soup.find('main')
    stations = main.find_all('section')

    station_names = []
    for station in stations:
        station_name_elements = station.find_all('span', class_='features-title')

        for station_name_element in station_name_elements:
            station_name = station_name_element.text.strip()
            cleaned_name = re.sub(r'^\d+[\.\s]', '', station_name).strip()
            station_names.append(cleaned_name)

    return station_names

# %%
districts = {}
for district_link in district_links:
    print(f"Парсим округ: {district_link}")
    district_name = district_link.split("/")[-1].replace("moscow_metro_", "").replace(".html", "")
    districts[district_name] = parse_district_page(district_link),
# Out:
# Парсим округ: https://domokucha.info/./moscow_metro_01_VAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_02_ZAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_03_SAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_04_SZAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_05_SVAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_06_CAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_07_UVAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_08_UZAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_09_UAO.html
# Парсим округ: https://domokucha.info/./moscow_metro_10_Zelenograd.html
# Парсим округ: https://domokucha.info/./moscow_metro_11_New-moscow.html
# Парсим округ: https://domokucha.info/./moscow_metro_12_Troicky.html

# %%
districts
# Out:
# {'01_VAO': (['Щёлковская',
#    'Первомайская,',
#    'Измайловская,',
#    'Партизанская',
#    'Семеновская',
#    'Электрозаводская',
#    'Новокосино',
#    'Новогиреево',
#    'Перово',
#    'Шоссе Энтузиастов',
#    'Бульвар Рокоссовского',
#    'Черкизовская',
#    'Преображенская Площадь',
#    'Сокольники',
#    'Выхино'],),
#  '02_ZAO': (['Крылатское',
#    'Молодежная',
#    'Кунцевская',
#    'Славянский бульвар',
#    'Парк Победы',
#    'Киевская',
#    'Киевская',
#    'Воробьёвы горы',
#    'Университет',
#    'Проспект Вернадского',
#    'Юго-Западная',
#    'Тропарёво',
#    'Кунцевская',
#    'Пионерская,',
#    'Филевский Парк',
#    'Багратионовская',
#    'Фили',
#    'Кутузовская',
#    'Студенческая',
#    'Киевская',
#    'Кутузовcкая',
#    'Площадь Гагарина'],),
#  '03_SAO': (['Савёловская',
#    'Ховрино',
#    'Беломорская',
#    'Речной вокзал',
#    'Водный стадион',
#    'Войковская',
#    'Сокол',
#    'Аэропорт',
#    'Динамо',
#    'Полежаевская',
#    'Беговая',
#    'Петровско-Разумовская',
#    'Тимирязевская',
#    'Савёловская',
#    'Тимирязевская',
#    'Окружная',
#    'Лихоборы (Николаевская)',
#    'Коптево',
#    'Балтийская (Войковская)',
#    'Стрешнево',
#    'Панфиловская (Ходынка)',
#    'Зорге (Новопесчаная)',
#    'Хорошёво',
#    'Петровский парк',
#    'Хорошёвская',
#    'ЦСКА'],),
#  '04_SZAO': (['Планерная',
#    'Сходненская',
#    'Тушинская',
#    'Октябрьское Поле',
#    'Спартак',
#    'Щукинская',
#    'Воробьёвы горы',
#    'Университет',
#    'Стрешнево',
#    'Панфиловская (Ходынка)',
#    'Зорге (Новопесчаная)',
#    'Хорошёво'],),
#  '05_SVAO': (['Савёловская',
#    'Медведково',
#    'Бабушкинская',
#    'Свиблово',
#    'Ботанический сад',
#    'ВДНХ',
#    'Алексеевская',
#    'Алтуфьево',
#    'Бибирево',
#    'Отрадное',
#    'Владыкино',
#    'Петровско-Разумовская',
#    'Тимирязевская',
#    'Дмитровская',
#    'Савеловская',
#    'Савёловская',
#    'Улица Сергея Эйзенштейна',
#    'Выставочный центр',
#    'Улица Академика Королёва',
#    'Телецентр',
#    'Улица Милашенкова',
#    'Тимирязевская',
#    'Владыкино',
#    'Окружная',
#    'Ростокино (Ярославская)',
#    'Ботанический сад'],),
#  '06_CAO': (['Смоленская',
#    'Арбатская',
#    'Площадь Революции',
#    'Курская',
#    'Бауманская',
#    'Белорусская (радиальная)',
#    'Маяковская',
#    'Тверская',
#    'Театральная',
#    'Новокузнецкая',
#    'Павелецкая (радиальная)',
#    'Третьяковская',
#    'Марксистская',
#    'Площадь Ильича',
#    'Рижская',
#    'Проспект Мира',
#    'Сухаревская',
#    'Тургеневская',
#    'Китай-город',
#    'Третьяковская',
#    'Октябрьская',
#    'Белорусская (кольцевая)',
#    'Новослободская',
#    'Проспект Мира',
#    'Комсомольская',
#    'Курская',
#    'Таганская',
#    'Павелецкая (кольцевая)',
#    'Добрынинская',
#    'Октябрьская',
#    'Парк Культуры',
#    'Краснопресненская (кольцевая)',
#    'Менделеевская',
#    'Цветной Бульвар',
#    'Чеховская',
#    'Боровицкая',
#    'Полянка',
#    'Серпуховская',
#    'Красносельская',
#    'Комсомольская',
#    'Красные Ворота',
#    'Чистые Пруды',
#    'Лубянка',
#    'Охотный Ряд',
#    'Библиотека им. Ленина',
#    'Кропоткинская',
#    'Парк Культуры',
#    'Фрунзенская',
#    'Спортивная',
#    'Воробьёвы горы',
#    'Улица 1905 года',
#    'Баррикадная',
#    'Пушкинская',
#    'Кузнецкий Мост',
#    'Китай-город',
#    'Таганская',
#    'Пролетарская',
#    'Смоленская',
#    'Арбатская',
#    'Александровский Сад',
#    'Шелепиха',
#    'Деловой центр',
#    'Лужники',
#    'Деловой центр',
#    'Шелепиха'],),
#  '07_UVAO': (['Авиамоторная',
#    'Дубровка',
#    'Кожуховская',
#    'Печатники',
#    'Волжская',
#    'Люблино',
#    'Братиславская',
#    'Марьино',
#    'Волгоградский Проспект',
#    'Кузьминки',
#    'Рязанский Проспект',
#    'Текстильщики',
#    'Дубровка',
#    'Угрешская (Волгоградская)',
#    'Новохохловская',
#    'Нижегородская (Рязанская)',
#    'Андроновка'],),
#  '08_UZAO': (['Битцевский Парк',
#    'Академическая',
#    'Беляево',
#    'Калужская',
#    'Коньково',
#    'Ленинский Проспект',
#    'Новоясеневская (Битцевский парк)',
#    'Новые Черемушки',
#    'Профсоюзная',
#    'Теплый Стан',
#    'Ясенево',
#    'Каховская',
#    'Бульвар Дмитрия Донского',
#    'Нахимовский проспект',
#    'Севастопольская',
#    'Чертановская',
#    'Тропарёво',
#    'Университет',
#    'Крымская'],),
#  '09_UAO': (['Автозаводская',
#    'Технопарк',
#    'Коломенская',
#    'Каширская',
#    'Кантемировская',
#    'Царицыно',
#    'Орехово',
#    'Домодедовская',
#    'Красногвардейская',
#    'Алма-Атинская',
#    'Шаболовская',
#    'Варшавская',
#    'Каширская',
#    'Тульская',
#    'Нагатинская',
#    'Нагорная',
#    'Чертановская',
#    'Южная',
#    'Пражская',
#    'Улица Академика Янгеля',
#    'Аннино',
#    'Крымская',
#    'Верхние Котлы (Варшавская)',
#    'ЗИЛ',
#    'Автозаводская'],),
#  '10_Zelenograd': (['Собянин: МЦД-3 «Зеленоград – Раменское» построят за два-три года',
#    'МЦД-3 от Зеленограда до Раменского'],),
#  '11_New-moscow': (['Румянцево',
#    'Саларьево',
#    'Филатов Луг',
#    'Прокшино',
#    'Ольховая',
#    'Коммунарка',
#    'Рассказовка',
#    'Говорово',
#    'Метро в Новой Москве'],),
#  '12_Troicky': (['Коммунарская линия метро', 'Метро придет в Троицк'],)}

# %%
metro_data = pd.read_csv('metro.tsv', sep='\t')
metro_data
# Out:
#                 Название     Широта    Долгота
# 0               Аэропорт  55.799810  37.534120
# 1          Академическая  55.688080  37.575010
# 2           Алексеевская  55.807370  37.638440
# 3    Александровский сад  55.752190  37.608360
# 4              Алтуфьево  55.895040  37.586050
# ..                   ...        ...        ...
# 160       Воробьёвы горы  55.710454  37.558601
# 161               Выхино  55.715000  37.818020
# 162              Ясенево  55.605350  37.534940
# 163         Юго-западная  55.664640  37.484210
# 164                Южная  55.621220  37.607520
#
# [165 rows x 3 columns]

# %%
colors = [
    "red", "green", "blue", "orange", "purple", "darkblue", "darkgreen", "darkred",
    "lightred", "beige", "darkpurple", "white", "pink", "cadetblue", "lightblue",
    "lightgreen", "gray", "black", "lightgray"
]

def get_unique_color(assigned_colors):
    available_colors = [color for color in colors if color not in assigned_colors]
    if available_colors:
        color = random.choice(available_colors)
        assigned_colors.add(color)
        return color

# %%
map_moscow = folium.Map(location=[55.7558, 37.6173], zoom_start=11)
assigned_colors = set()

for district, (stations,) in districts.items():
    district_color = get_unique_color(assigned_colors)
    for station in stations:
        station_data = metro_data[metro_data['Название'] == station]

        if not station_data.empty:
            lat = station_data.iloc[0]['Широта']
            lon = station_data.iloc[0]['Долгота']
            print(district_color)
            folium.Marker(
                location=[lat, lon],
                popup=f"{station}<br>Координаты: {lat}, {lon}, {district_color}",
                icon=folium.Icon(color=district_color)
            ).add_to(map_moscow)
        # else:
            # print(station)
# Out:
# darkgreen
# darkgreen
# darkgreen
# darkgreen
# darkgreen
# darkgreen
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgray
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# lightgreen
# beige
# beige
# beige
# beige
# beige
# green
# green
# green
# green
# green
# green
# green
# green
# green
# green
# green
# green
# green
# green
# green
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# darkpurple
# pink
# pink
# pink
# pink
# pink
# pink
# pink
# pink
# pink
# pink
# red
# red
# red
# red
# red
# red
# red
# red
# red
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred
# lightred

# %%
map_moscow
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8197f8d655089282602e012dd3697d31 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8197f8d655089282602e012dd3697d31&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8197f8d655089282602e012dd3697d31 = L.map(
#                 &quot;map_8197f8d655089282602e012dd3697d31&quot;,
#                 {
#                     center: [55.7558, 37.6173],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cd031e5aec2de219d46663a5ab04ba51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cd031e5aec2de219d46663a5ab04ba51.addTo(map_8197f8d655089282602e012dd3697d31);
#
#
#             var marker_42e905a9d69587ce0d6fdf50264202b6 = L.marker(
#                 [55.78962, 37.7479],
#                 {}
#             ).addTo(map_8197f8d655089282602e012dd3697d31);
#
#
#             var icon_3877b939c45376e3156821447c487faa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_42e905a9d69587ce0d6fdf50264202b6.setIcon(icon_3877b939c45376e3156821447c487faa);
#
#
#         var popup_d57ebfa14322681141830a010e2a5853 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_feb30ddda6f0a1cda0d3bd71c2ba44a4 = $(`&lt;div id=&quot;html_feb30ddda6f0a1cda0d3bd71c2ba44a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Партизанская&lt;br&gt;Координаты: 55.78962, 37.7479, darkgreen&lt;/div&gt;`)[0];
#                 popup_d57ebfa14322681141830a010e2a5853.setContent(html_feb30ddda6f0a1cda0d3bd71c2ba44a4);
#
#
#
#         marker_42e905a9d69587ce0d6fdf50264202b6.bindPopup(popup_d57ebfa14322681141830a010e2a5853)
#         ;
#
#
#
#
#             var marker_02599aa3b298287fdc76fb18cc9a360f = L.marker(
#                 [55.78177, 37.70471],
#                 {}
#             ).addTo(map_8197f8d655089282602e012dd3697d31);
#
#
#             var icon_4551be2ef3ddc2f38218590eae5932aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_02599aa3b298287fdc76fb18cc9a360f.setIcon(icon_4551be2ef3ddc2f38218590eae5932aa);
#
#
#         var popup_ebdaeb0668e21292739092e71e7839b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecefc31276aae4ec535c7ab3b2da9f47 = $(`&lt;div id=&quot;html_ecefc31276aae4ec535c7ab3b2da9f47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Электрозаводская&lt;br&gt;Координаты: 55.78177, 37.70471, darkgreen&lt;/div&gt;`)[0];
#                 popup_ebdaeb0668e21292739092e71e7839b6.setContent(html_ecefc31276aae4ec535c7ab3b2da9f47);
#
#
#
#         marker_02599aa3b298287fdc76fb18cc9a360f.bindPopup(popup_ebdaeb0668e21292739092e71e7839b6)
#         ;
#
#
#
#
#             var marker_9056bcddc51dd4df6984df80da8337f3 = L.marker(
#                 [55.75111, 37.81564],
#                 {}
#             ).addTo(map_8197f8d655089282602e012dd3697d31);
#
#
#             var icon_ea57482e605bf521049772dc5bebe5cd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9056bcddc51dd4df6984df80da8337f3.setIcon(icon_ea57482e605bf521049772dc5bebe5cd);
#
#
#         var popup_e433d17b57df15ac0a437f085c18aec9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d5f8117d7dfdd945bd6868ef4853ec0 = $(`&lt;div id=&quot;html_6d5f8117d7dfdd945bd6868ef4853ec0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Новогиреево&lt;br&gt;Координаты: 55.75111, 37.81564, darkgreen&lt;/div&gt;`)[0];
#                 popup_e433d17b57df15ac0a437f085c18aec9.setContent(html_6d5f8117d7dfdd945bd6868ef4853ec0);
#
#
#
#         marker_9056bcddc51dd4df6984df80da8337f3.bindPopup(popup_e433d17b57df15ac0a437f085c18aec9)
#         ;
#
#
#
#
#             var marker_74b962f1851af85e823c2d412fd2d6de = L.marker(
#                 [55.75109, 37.78854],
#                 {}
#             ).addTo(map_8197f8d655089282602e012dd3697d31);
#
#
#             var icon_65c069bfcbe17d9ac424752497810592 = L.AwesomeMarkers.icon(
